# %%
import matplotlib.pyplot as plt

# %%
rewards=[-10, -4.180851758074319, -5.157823794755622, -6.1169031183859675, -8.05711567696418, -10, 0.6328255748838778, -5.178282722288761, -8.0577041766513, -10]
plt.plot(rewards)
# plt.savefig('./rewards.eps')
# plt.savefig('./rewards.pdf')
